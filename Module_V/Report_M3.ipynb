# %% [markdown]
# # 3.1 Выступление участника

# %% [markdown]
# **В ходе работы над этим модулем, я подготовил презентацию в формате pptx, в которой охватил все аспекты выполненного задания. Презентация содержит описание результатов работы с обосновнием выбора конкретных решений. Также презентация содержит в себе скриншоты результатов работы. Основной формат презентации соответствует формату "Печа-куча"**

# %% [markdown]
# # 3.2 Разделы презентации

# %% [markdown]
# **Презентация структурирована и охватывает все аспекты выполненного задания. В ней отражены отчеты о работе с данными, описаны выбранные алгоримты работы нейросети.**
#
# *Структура:*
#
# - 1. `титульник `
# - 2. `модуль А библиотеки`
# - 3. `модуль А 1.1 анализ классов`
# - 4. `модуль А 1.1 подготовка данных (оставляем 1 класс)`
# - 5. `модуль А 1.2 yolo + гиперпараметры`
# - 6. `модуль А 1.3 импорт данных + структура данных`
# - 7. `модуль А 1.4 тестирование модели, 3 эпохи + результаты `
# - 8. `модуль А 1.4 обучение модели, 10 эпох + результаты`
# - 9. `модуль А 1.4 проверка, показ работы модел`
# - 10. `модуль А 1.4 выбор OCR модели`
# - 11. `модуль А 1.4 создание функции, алгоритм работы`
# - 12. `модуль А 1.4 рефлексия`
# - 13. `модуль Б 2.1 кейс 1       экспериментальные кейсы`
# - 14. `модуль Б 2.1 кейсы 2      экспериментальные кейсы`
# - 15. `модуль Б 2.1 кейсы 3      экспериментальные кейсы`
# - 15. `модуль Б 2.1 кейсы 4, 5   тестовый кейс из интернета для обоих магазинов`
# - 16. `модуль Б 2.1 кейсы 6, 7   тестовый кейс из тестового датасета`
# - 18. `модуль Б 2.1 рефлексия`
# - 19. `модуль В 3.1 сделал презентацию`
# - 20. `рефлексия по проделанной работе`

# %% [markdown]
# # 3.3 Оформление презентации

# %% [markdown]
# **Презентация выполнена в деловом стиле с сохранением структуры.**
#
# **На слайдам представлена визуализированая информация в виде графиков, что способствует лучшему восприятию.**
#
# **Текстовая информация минимизирована для улучшения читаемости и визуальной привлекательности**
